# %% [markdown]
# <a href="https://colab.research.google.com/github/Misharosejoseph/Machine-learning-project/blob/main/Copy_of_K_MEAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 🎓 Example dataset: Study Hours vs Sleep Hours
data = {
    "Study_Hours": [1, 2, 2, 3, 4, 5, 6, 6, 7, 8],
    "Sleep_Hours": [8, 7, 7.5, 6.5, 6, 5.5, 5, 4.5, 4, 3.5]
}
df = pd.DataFrame(data)

# 🔹 Apply K-Means with 2 clusters
kmeans = KMeans(n_clusters=2, random_state=42)
df["Cluster"] = kmeans.fit_predict(df[["Study_Hours", "Sleep_Hours"]])

print("Cluster Centers:")
print(kmeans.cluster_centers_)
print("\nClustered Data:")
print(df)

# 📊 Plot the clusters
plt.scatter(df["Study_Hours"], df["Sleep_Hours"],
            c=df["Cluster"], cmap="viridis", s=100)
plt.scatter(kmeans.cluster_centers_[:,0],
            kmeans.cluster_centers_[:,1],
            c="red", marker="X", s=200, label="Centers")
plt.xlabel("Study Hours per Day")
plt.ylabel("Sleep Hours per Day")
plt.title("K-Means Clustering of Students")
plt.legend()
plt.show()
# Out:
# Cluster Centers:
# [[2.4 7. ]
#  [6.4 4.5]]
#
# Clustered Data:
#    Study_Hours  Sleep_Hours  Cluster
# 0            1          8.0        0
# 1            2          7.0        0
# 2            2          7.5        0
# 3            3          6.5        0
# 4            4          6.0        0
# 5            5          5.5        1
# 6            6          5.0        1
# 7            6          4.5        1
# 8            7          4.0        1
# 9            8          3.5        1
